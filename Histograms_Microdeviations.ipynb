# %%
# %matplotlib inline
import numpy as np
import scipy
import matplotlib.pyplot as plt
import IPython.display
import essentia
import essentia.standard as es
import librosa
import librosa.display
from collections import Counter
from utils import *
import pandas as pd
import seaborn as sns

# %%
heatmap_draw('drummer1_allinstruments.csv', 'Drummmer1 - Phrases 36-89 // Microdeviations around ideal sixteenths', 'drummer1_phrases.all_instruments.jpg')

# %%
heatmap_draw('drummer1_bass.csv', 'Drummmer1 - Bass drum// Microdeviations around ideal sixteenths', 'drummer1_phrases.bass_drum.jpg')

# %%
heatmap_draw('drummer1_snare.csv', 'Drummmer1 - Snare // Microdeviations around ideal sixteenths', 'drummer1_phrases.snare_drum.jpg')

# %%
heatmap_draw('drummer1_hihat_cymbal.csv', 'Drummmer1 - Hi-hat // Microdeviations around ideal sixteenths', 'drummer1_phrases.hihat.jpg')

# %%
heatmap_draw('drummer1_toms.csv', 'Drummmer1 - Toms // Microdeviations around ideal sixteenths', 'drummer1_phrases.toms.jpg')

# %%
heatmap_draw('drummer1_cymbals.csv', 'Drummmer1 - Cymbals // Microdeviations around ideal sixteenths', 'drummer1_phrases.cymbals.jpg')
